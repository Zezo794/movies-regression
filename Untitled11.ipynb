# %%
import pandas as pd
import json
import pickle
from sklearn.model_selection import GridSearchCV,\
RandomizedSearchCV
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import LinearSVC
from sklearn.linear_model import LinearRegression, RidgeCV
import seaborn as sns
import os
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import MinMaxScaler, StandardScaler, Normalizer, FunctionTransformer, PolynomialFeatures, \
    LabelEncoder, MultiLabelBinarizer
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectPercentile
from sklearn.feature_selection import chi2, f_classif
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score, precision_score
from sklearn.pipeline import Pipeline
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn import metrics
from sklearn.feature_selection import SelectKBest , f_classif
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing
import pandas as pd
import nltk
import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize
import re
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
#nltk.download('wordnet')
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import VarianceThreshold, SelectKBest, chi2
from sklearn.metrics import mean_squared_error, r2_score
def NumericPreProcessing(df,df2):
 
    # removing zeros
    df[['budget',  'viewercount', 'revenue', 'runtime', 'vote_count','release_date']] \
        = df[['budget',  'viewercount', 'revenue', 'runtime', 'vote_count','release_date']]\
        .replace(0, df[['budget',  'viewercount', 'revenue', 'runtime','vote_count','release_date']].mean())
 
    # scaling
    cols_to_scale = ['viewercount',  'vote_count','budget','revenue','release_date']
    df[cols_to_scale] = (df[cols_to_scale] - df[cols_to_scale].min()) / (df[cols_to_scale].max() - df[cols_to_scale].min())
    
    cols = df[cols_to_scale]
#     cols = pd.concat([cols, df2], axis = 1)
#     corr = cols.corr()
#     # Top 50% Correlation training features with the Value
#     top_feature = corr.index[abs(corr['vote_average']) > 0.05]

#     top_corr = cols[top_feature].corr()
#     print(top_corr)

#     top_feature = top_feature.delete(-1)
#    # top_feature= pd.DataFrame(top_feature.toarray(),columns=Tag_vectorizer.get_feature_names_out())
#     top_feature= pd.DataFrame(top_feature)
    return cols
 
def colsToNormalize(df):
 
    data = pd.DataFrame()
    df['homepage'] = df['homepage'].notnull().astype(int)
    #data = pd.concat([data, df['homepage']], axis=1)
    df['status'] = df['status'].notnull().astype(int)
    #data = pd.concat([data, df['status']], axis = 1)
 
    le = preprocessing.LabelEncoder()
    df['original_language'] = le.fit_transform(df['original_language'])
    df['original_language'] = le.fit_transform(df.original_language.values)
 
    data = pd.concat([data, df['original_language']], axis=1)
    return data
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))
def preprocess_text(text):
    if pd.isna(text):
        text = ''
    # Convert to lowercase
    text = text.lower()
    # Remove non-alphanumeric characters
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    # Tokenize the text into words
    tokens = word_tokenize(text)
    # Remove stop words
    tokens = [token for token in tokens if token not in stop_words]
    # Perform lemmatization
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    # Join the list of tokens into a single string
    text = ' '.join(tokens)
    return text
mlb_key = MultiLabelBinarizer()
mlbgen = MultiLabelBinarizer()
mlbpc = MultiLabelBinarizer()
mlb2 = MultiLabelBinarizer()
mlbsp = MultiLabelBinarizer()
def dictionaryPreprocessing(df):
    data = pd.DataFrame()
 
    # Convert the 'genres' column to a list of genre names
    df['genres'] = df['genres'].apply(lambda x: ','.join([d['name'] for d in eval(x)]))
 
    df['keywords'] = df['keywords'].apply(lambda x: ','.join([d['name'] for d in eval(x)]))
 
    df['production_companies'] = df['production_companies'].apply(lambda x: ','.join([d['name'] for d in eval(x)]))
 
    # Convert the 'production_countries' column to a list of country names
    df['production_countries'] = df['production_countries'].apply(
        lambda x: ','.join([d['iso_3166_1'] for d in eval(x)]))
 
    # Convert the 'spoken_languages' column to a list of language names
    df['spoken_languages'] = df['spoken_languages'].apply(lambda x: ','.join([d['name'] for d in eval(x)]))
 
    mlb_key.fit(df['keywords'])
    transkey = mlb_key.transform(df['keywords'])
    transskey = pd.DataFrame(transkey)
    #data = pd.concat([data,transskey],axis=1)
    
    
    mlbgen.fit(df['genres'])
    transgen = mlbgen.transform(df['genres'])
    transsgen = pd.DataFrame(transgen)
    data = pd.concat([data,transsgen],axis=1)
 
 
    mlbpc.fit(df['production_countries'])
    transpc = mlbpc.transform(df['production_countries'])
    transspc = pd.DataFrame(transpc)
    data = pd.concat([data,transspc],axis=1)
 
 
    mlbsp.fit(df['spoken_languages'])
    transp = mlbsp.transform(df['spoken_languages'])
    transsp = pd.DataFrame(transp)
    data = pd.concat([data,transsp],axis=1)
    
 
 
    mlb2.fit(df['production_companies'])
    trans2 = mlb2.transform(df['production_companies'])
    transs2 = pd.DataFrame(trans2)
    data = pd.concat([data,transs2],axis=1)
  
    return data
def dictionaryPreprocessing_test(df):
    data = pd.DataFrame()
    
    # Convert the 'genres' column to a list of genre names
    df['genres'] = df['genres'].apply(lambda x: ','.join([d['name'] for d in eval(x)]))
 
    df['keywords'] = df['keywords'].apply(lambda x: ','.join([d['name'] for d in eval(x)]))
 
    df['production_companies'] = df['production_companies'].apply(lambda x: ','.join([d['name'] for d in eval(x)]))
 
    # Convert the 'production_countries' column to a list of country names
    df['production_countries'] = df['production_countries'].apply(
        lambda x: ','.join([d['iso_3166_1'] for d in eval(x)]))
 
    # Convert the 'spoken_languages' column to a list of language names
    df['spoken_languages'] = df['spoken_languages'].apply(lambda x: ','.join([d['name'] for d in eval(x)]))
 
   
    transkey = mlb_key.transform(df['keywords'])
    transskey = pd.DataFrame(transkey)
    #data = pd.concat([data, transskey], axis=1)
    
    
    transgen = mlbgen.transform(df['genres'])
    transsgen = pd.DataFrame(transgen)
    data = pd.concat([data, transsgen], axis=1)
 
   
    transpc = mlbpc.transform(df['production_countries'])
    transspc = pd.DataFrame(transpc)
    data = pd.concat([data, transspc], axis=1)
 
   
    transp = mlbsp.transform(df['spoken_languages'])
    transsp = pd.DataFrame(transp)
    data = pd.concat([data, transsp], axis=1)
    
 
   
    trans2 = mlb2.transform(df['production_companies'])
    transs2 = pd.DataFrame(trans2)
    data = pd.concat([data,transs2],axis=1)
   
    return data
df = pd.read_csv(r'C:/Users/Asus/Desktop/movies-regression/movies-regression-dataset.csv', parse_dates=['release_date'],
                 dayfirst=True,engine='python')
df.drop_duplicates(inplace=True)

df['release_date'] = pd.to_datetime(df['release_date'])
reference_date = datetime.now()
df['release_date'] = (reference_date - df['release_date']).dt.days
X_train= df.iloc[:, :-1]
y_train= df['vote_average']

#X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, shuffle=False, random_state=1000)
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/17/1994' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/26/2008' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/18/1969' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/13/1994' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/22/2010' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/25/1997' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/22/1989' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/16/2015' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/24/2003' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/21/1986' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/25/1998' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/16/2001' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/22/2004' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/20/2006' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/23/2005' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/19/2008' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/20/1989' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/18/2008' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/24/1999' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/14/2003' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/14/1984' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/15/2013' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/16/1993' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/14/2000' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/24/1997' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/25/2002' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/19/1994' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/16/2006' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/21/2002' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/30/1998' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/24/1978' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/14/2006' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/25/1991' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/22/2008' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/22/1965' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/26/2010' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/20/2007' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/24/2003' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/26/1999' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/28/2010' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/21/1983' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/19/2002' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/25/2003' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/25/2011' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/16/2009' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/13/2000' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/31/2002' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/25/1959' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/23/1954' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/19/2015' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/14/1996' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/18/2001' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/14/2011' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/17/2002' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/24/2010' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/14/2011' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/18/1975' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/22/1999' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/22/1999' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/25/1993' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/13/2002' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/15/2006' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/17/1998' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/27/2000' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/21/2001' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/17/2009' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/15/1999' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/16/2010' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/23/1988' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/21/2001' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/17/2010' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/18/2010' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/21/2011' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/21/1997' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/26/2004' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/19/2009' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/24/1993' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/17/1999' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/22/2005' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/15/2011' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/16/1998' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/14/2002' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/20/1997' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/29/1995' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/27/2013' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/30/2015' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/23/2009' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/17/1997' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/20/2010' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/14/2015' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/17/2005' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/17/2011' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/21/1987' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/31/1946' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/25/2009' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/30/1982' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/28/2009' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/13/2006' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/16/1995' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/13/2004' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/18/2011' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/24/2011' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/30/2008' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/25/1992' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/24/2014' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/30/2005' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/19/2004' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/26/1997' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/21/2005' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/17/2008' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/18/1975' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/18/1983' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/27/2007' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/18/1996' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/26/2002' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/27/2009' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/16/2005' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/24/1990' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/13/2005' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/23/2014' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/18/2012' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/22/2002' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/25/2003' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/29/1984' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/13/1992' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/21/1994' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/18/2013' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/17/2000' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/15/1996' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/13/1995' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/17/2004' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/23/2010' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/25/2014' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/13/2007' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/13/1979' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/21/1988' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/15/1991' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/27/2007' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/15/1996' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/31/2014' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/29/2010' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/23/2008' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/27/2008' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/31/1997' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/15/2015' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/30/2015' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/22/2000' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/19/1989' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/15/2009' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/20/1989' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/25/1998' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/23/1994' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/18/1961' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/24/2000' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/16/2009' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/17/1990' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/27/2006' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/16/2002' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/20/1985' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/13/1978' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/22/2011' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/21/1988' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/20/2012' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/18/2012' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/30/2001' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/22/1993' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/19/2000' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/19/1980' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/23/1991' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/21/2007' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/29/2013' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/13/1987' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/22/1995' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/29/2012' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/19/2007' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/22/2006' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/14/2001' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/29/2000' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/25/1986' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/13/2009' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/15/2008' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/22/2006' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/25/1984' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/21/2007' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/15/1998' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/23/2013' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/14/2015' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/25/2015' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/26/2015' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/14/1984' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/17/2001' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/17/1993' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/17/2007' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/18/1997' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/19/2001' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/26/2001' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/24/2015' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/25/2007' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# ...
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/25/2007' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/18/1996' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/16/1988' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/21/2005' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/25/2002' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/21/2012' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/25/1973' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/18/1988' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/26/2012' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/22/1982' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/14/2002' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/26/1984' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/19/2014' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/18/1979' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/17/2014' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/28/1999' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/26/2009' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/22/2011' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/22/2013' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/27/2002' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/26/2003' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/21/2009' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/19/1992' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/25/2005' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/14/1997' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/13/2006' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/16/2013' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/13/1998' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/21/2003' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/15/2002' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/28/2007' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/19/2011' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/26/2015' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/25/2010' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/20/2007' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/28/2011' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/24/2004' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/30/2011' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/25/2011' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/14/2006' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/19/2003' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/20/1990' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/26/2001' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/25/2013' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/25/2012' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/21/1968' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/23/2003' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/18/1999' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/13/2011' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/18/2009' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/18/1992' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/16/2014' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/27/1987' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/23/2001' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/31/2008' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/20/2009' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/20/2006' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/14/2001' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/17/2004' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/18/1985' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/13/2015' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/21/2006' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '10/13/1988' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/26/1973' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '11/17/2006' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(
# C:\Users\Asus\anaconda3\lib\site-packages\pandas\io\parsers\base_parser.py:1070: UserWarning: Parsing '12/20/1979' in MM/DD/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   return tools.to_datetime(

# %%
df_test = pd.read_csv(r'C:\Users\Nouran\OneDrive\Desktop\movies-tas-test.csv', parse_dates=['release_date'],
                 dayfirst=True,engine='python')
# df_test.drop_duplicates(inplace=True)

df_test['release_date'] = pd.to_datetime(df_test['release_date'])
reference_date = datetime.now()
df_test['release_date'] = (reference_date - df_test['release_date']).dt.days
X_test= df.iloc[:, :-1]
y_test= df['vote_average']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4452\51289083.py in <module>
# ----> 1 df_test = pd.read_csv(r'C:\Users\Nouran\OneDrive\Desktop\movies-tas-test.csv', parse_dates=['release_date'],
#       2                  dayfirst=True,engine='python')
#       3 # df_test.drop_duplicates(inplace=True)
#       4
#       5 df_test['release_date'] = pd.to_datetime(df_test['release_date'])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     676     kwds.update(kwds_defaults)
#     677
# --> 678     return _read(filepath_or_buffer, kwds)
#     679
#     680
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _read(filepath_or_buffer, kwds)
#     573
#     574     # Create the parser.
# --> 575     parser = TextFileReader(filepath_or_buffer, **kwds)
#     576
#     577     if chunksize or iterator:
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in __init__(self, f, engine, **kwds)
#     930
#     931         self.handles: IOHandles | None = None
# --> 932         self._engine = self._make_engine(f, self.engine)
#     933
#     934     def close(self):
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py in _make_engine(self, f, engine)
#    1214             # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215             # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216             self.handles = get_handle(  # type: ignore[call-overload]
#    1217                 f,
#    1218                 mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784         if ioargs.encoding and "b" not in ioargs.mode:
#     785             # Encoding
# --> 786             handle = open(
#     787                 handle,
#     788                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Nouran\\OneDrive\\Desktop\\movies-tas-test.csv'

# %%
X_train['overview'] = X_train['overview'].apply(preprocess_text)
X_test['overview'] = X_test['overview'].apply(preprocess_text)

X_train['title']= X_train['title'].apply(preprocess_text)
X_test['title']=  X_test['title'].apply(preprocess_text)

X_train['tagline']= X_train['tagline'].apply(preprocess_text)
X_test['tagline']=  X_test['tagline'].apply(preprocess_text)

X_train['original_title']= X_train['original_title'].apply(preprocess_text)
X_test['original_title']=  X_test['original_title'].apply(preprocess_text)
Tag_vectorizer = TfidfVectorizer()

tagtrain = Tag_vectorizer.fit_transform(X_train['tagline'])
tag_train= pd.DataFrame(tagtrain.toarray(),columns=Tag_vectorizer.get_feature_names_out())

tag_test = Tag_vectorizer.transform(X_test['tagline'])
tag_test= pd.DataFrame(tag_test.toarray(),columns=Tag_vectorizer.get_feature_names_out())
OTitle_vectorizer = TfidfVectorizer()
Otitle_train = OTitle_vectorizer.fit_transform(X_train['original_title'])
Otitle_train= pd.DataFrame(Otitle_train.toarray(),columns=OTitle_vectorizer.get_feature_names_out())
Otitle_test = OTitle_vectorizer.transform(X_test['original_title'])
Otitle_test= pd.DataFrame(Otitle_test.toarray(),columns=OTitle_vectorizer.get_feature_names_out())
Title_vectorizer = TfidfVectorizer()
title_train = Title_vectorizer.fit_transform(X_train['title'])
title_train= pd.DataFrame(title_train.toarray(),columns=Title_vectorizer.get_feature_names_out())
title_test = Title_vectorizer.transform(X_test['title'])
title_test= pd.DataFrame(title_test.toarray(),columns=Title_vectorizer.get_feature_names_out())
vectorizer = TfidfVectorizer()
nlp_train = vectorizer.fit_transform(X_train['overview'])
nlp_train= pd.DataFrame(nlp_train.toarray(),columns=vectorizer.get_feature_names_out())
nlp_test = vectorizer.transform(X_test['overview'])
nlp_test= pd.DataFrame(nlp_test.toarray(),columns=vectorizer.get_feature_names_out())
dataAbdallah = pd.DataFrame()
dataAbdallah = pd.concat([dataAbdallah, colsToNormalize(X_train)], axis=1)
print("norm")
print(dataAbdallah.shape)
dataAbdallah = dataAbdallah.reset_index(drop=True,inplace=True)


dataAbdallah = pd.concat([dataAbdallah,NumericPreProcessing(X_train,y_train) ], axis=1)

 
print("num")
print(dataAbdallah.shape)
selector = VarianceThreshold(threshold=0.11)
X_train_selected = selector.fit_transform(dictionaryPreprocessing(X_train))
X_test_selected = selector.transform(dictionaryPreprocessing_test(X_test))
X_train_selected= pd.DataFrame(X_train_selected)
X_test_selected= pd.DataFrame(X_test_selected) 

'''X_train_selected = pd.DataFrame()
X_test_selected = pd.DataFrame()
X_train_selected = dictionaryPreprocessing(X_train)
X_test_selected = dictionaryPreprocessing_test(X_test)

s = X_train_selected.sum()
X_train_selected = X_train_selected.drop(s[s < 100].index, axis = 1)

#s2 = X_test_selected.sum()
X_test_selected = X_test_selected.drop(s[s < 100].index, axis = 1)'''

###
dataAbdallah = pd.concat([dataAbdallah,X_train_selected],axis=1)
print("dict")
print(dataAbdallah.shape)

#dataAbdallah= pd.concat([dataAbdallah,tag_train],axis=1)
# dataAbdallah= pd.concat([dataAbdallah,Otitle_train],axis=1)
#dataAbdallah= pd.concat([dataAbdallah,title_train],axis=1)
#dataAbdallah= pd.concat([dataAbdallah,nlp_train],axis=1)
#print("nlp")
#print(dataAbdallah.shape)
 
dataAbdallah = dataAbdallah.fillna(0)
################################

dataNaguib= pd.DataFrame()
dataNaguib = pd.concat([dataNaguib, colsToNormalize(X_test)], axis=1)
print("norm")
print(dataNaguib.shape)
dataNaguib = dataNaguib.reset_index(drop=True,inplace=True)

dataNaguib = pd.concat([dataNaguib,NumericPreProcessing(X_test,y_test) ], axis=1)
print("num")
print(dataNaguib.shape)
dataNaguib = dataNaguib.reset_index(drop=True)
 
dataNaguib = pd.concat([dataNaguib,X_test_selected],axis=1)
print("dict")
print(dataNaguib.shape)

#dataNaguib= pd.concat([dataNaguib,tag_test],axis=1)
# dataNaguib= pd.concat([dataNaguib,Otitle_test],axis=1)
#dataNaguib= pd.concat([dataNaguib,title_test],axis=1)
#dataNaguib= pd.concat([dataNaguib,nlp_test],axis=1)
#print("nlp")
#print(dataNaguib.shape)
 
dataNaguib = dataNaguib.fillna(0)
dataAbdallah.columns = dataAbdallah.columns.astype(str)
dataNaguib.columns = dataNaguib.columns.astype(str)
def linear_model():
    filename = 'LINEAR_model.sav'
    if os.path.exists('LINEAR_model.sav'):
        print("Loading Trained Model")
        # load the model from disk
        loaded_model = pickle.load(open(filename, 'rb'))
        ypred=loaded_model.predict(dataNaguib)
        r2 = r2_score(y_test, ypred)
        print('Mean Square Error linear regression', metrics.mean_squared_error(y_test, ypred))
        print('Score of linear regression:',loaded_model.score(dataNaguib, y_test))
        print('Score2 of linear regression:', r2)
        
        plt.figure(figsize=(5,5))
        plt.scatter(y_test, ypred, c='crimson')
        plt.yscale('log')
        plt.xscale('log')

        p1 = max(max(ypred), max(y_test))
        p2 = min(min(ypred), min(y_test))
        plt.plot([p1, p2], [p1, p2], 'b-')
        plt.xlabel('True Values', fontsize=15)
        plt.ylabel('Predictions', fontsize=15)
        plt.axis('equal')
        plt.show()
    else:
        print("Creating and training a new model")
        print("Model training started")
        print("Linear Regression")
        lr= LinearRegression()
        lr.fit(dataAbdallah,y_train)
        pickle.dump(lr, open(filename, 'wb'))
        ypred=lr.predict(dataNaguib)
        
        r2 = r2_score(y_test, ypred)
        print('Mean Square Error linear regression', metrics.mean_squared_error(y_test, ypred))
        print('Score of linear regression:',lr.score(dataNaguib, y_test))
        print('Score2 of linear regression:', r2)
        
        plt.figure(figsize=(5,5))
        plt.scatter(y_test, ypred, c='crimson')
        plt.yscale('log')
        plt.xscale('log')

        p1 = max(max(ypred), max(y_test))
        p2 = min(min(ypred), min(y_test))
        plt.plot([p1, p2], [p1, p2], 'b-')
        plt.xlabel('True Values', fontsize=15)
        plt.ylabel('Predictions', fontsize=15)
        plt.axis('equal')
        plt.show()
def random_model():
    filename = 'RANDOM_model.sav'
    if os.path.exists('RANDOM_model.sav'):
        print("Loading Trained Model")
        # load the model from disk
        loaded_model = pickle.load(open(filename, 'rb'))
        ypred=loaded_model.predict(dataNaguib)
        r2 = r2_score(y_test, ypred)
        print('Mean Square Error random forest', metrics.mean_squared_error(y_test, ypred))
        print('Score of random forest:',loaded_model.score(dataNaguib, y_test))
        print('Score2 of random forest:', r2)
        
        plt.figure(figsize=(5,5))
        plt.scatter(y_test, ypred, c='crimson')
        plt.yscale('log')
        plt.xscale('log')

        p1 = max(max(ypred), max(y_test))
        p2 = min(min(ypred), min(y_test))
        plt.plot([p1, p2], [p1, p2], 'b-')
        plt.xlabel('True Values', fontsize=15)
        plt.ylabel('Predictions', fontsize=15)
        plt.axis('equal')
        plt.show()
    else:
        print("Creating and training a new model")
        print("Model training started")
        print("random forest")
        rf=RandomForestRegressor()
        rf.fit(dataAbdallah,y_train)
        pickle.dump(rf, open(filename, 'wb'))
        ypred=rf.predict(dataNaguib)
        
        r2 = r2_score(y_test, ypred)
        print('Mean Square Error random forestn', metrics.mean_squared_error(y_test, ypred))
        print('Score of random forest:',rf.score(dataNaguib, y_test))
        print('Score2 of random forest:', r2)
        
        plt.figure(figsize=(5,5))
        plt.scatter(y_test, ypred, c='crimson')
        plt.yscale('log')
        plt.xscale('log')

        p1 = max(max(ypred), max(y_test))
        p2 = min(min(ypred), min(y_test))
        plt.plot([p1, p2], [p1, p2], 'b-')
        plt.xlabel('True Values', fontsize=15)
        plt.ylabel('Predictions', fontsize=15)
        plt.axis('equal')
        plt.show()
def ridgecv_model():
    filename = 'RidgeCV_model.sav'
    if os.path.exists('RidgeCV_model.sav'):
        print("Loading Trained Model")
        # load the model from disk
        loaded_model = pickle.load(open(filename, 'rb'))
        ypred=loaded_model.predict(dataNaguib)
        r2 = r2_score(y_test, ypred)
        print('Mean Square Error RidgeCV', metrics.mean_squared_error(y_test, ypred))
        print('Score of RidgeCV:',loaded_model.score(dataNaguib, y_test))
        print('Score2 of RidgeCV:', r2)
        
        plt.figure(figsize=(5,5))
        plt.scatter(y_test, ypred, c='crimson')
        plt.yscale('log')
        plt.xscale('log')

        p1 = max(max(ypred), max(y_test))
        p2 = min(min(ypred), min(y_test))
        plt.plot([p1, p2], [p1, p2], 'b-')
        plt.xlabel('True Values', fontsize=15)
        plt.ylabel('Predictions', fontsize=15)
        plt.axis('equal')
        plt.show()
    else:
        print("Creating and training a new model")
        print("Model training started")
        print("RidgeCV")
        model = RidgeCV()
        model.fit(dataAbdallah, y_train)
        pickle.dump(model, open(filename, 'wb'))
        ypred=model.predict(dataNaguib)
        
        r2 = r2_score(y_test, ypred)
        print('Mean Square Error RidgeCV', metrics.mean_squared_error(y_test, ypred))
        print('Score of RidgeCV:',model.score(dataNaguib, y_test))
        print('Score2 of RidgeCV:', r2)
        
        plt.figure(figsize=(5,5))
        plt.scatter(y_test, ypred, c='crimson')
        plt.yscale('log')
        plt.xscale('log')

        p1 = max(max(ypred), max(y_test))
        p2 = min(min(ypred), min(y_test))
        plt.plot([p1, p2], [p1, p2], 'b-')
        plt.xlabel('True Values', fontsize=15)
        plt.ylabel('Predictions', fontsize=15)
        plt.axis('equal')
        plt.show()

linear_model()
random_model()
ridgecv_model()
